# %%
import pandas as pd

# %%
file = pd.read_json("data.json", orient='index')
file
# Out:
#                                              response  token_count  \
# 0    The 2020 World Series was played in Arlington...           67
# 1    The 2020 World Series was played at Globe Lif...           57
# 2    Globe Life Field in Arlington, Texas. It was ...           36
# 3    The 2020 World Series was played at Globe Lif...          118
# 4                  Globe Life Field, Arlington, Texas            8
# 5                 Globe Life Field, Arlington, Texas.            9
# 6    The 2020 World Series was played at Globe Lif...          158
# 7    The 2020 World Series was played at Globe Lif...           61
# 8                Globe Life Field in Arlington, Texas            8
# 9    The 2020 World Series was played at Globe Lif...           94
# 10   Globe Life Field, located in Arlington, Texas...           24
# 11   The 2020 World Series was played at Globe Lif...          111
# 12   The 2020 World Series was played at Globe Lif...           53
# 13   The 2020 World Series was played at Globe Lif...           65
# 14   In 2020, the World Series was played at Globe...           78
# 15   Game 6 of the 2020 World Series was played at...           56
# 16   The 2020 World Series was played in Arlington...           79
# 17   The 2020 World Series was played at Globe Lif...           84
# 18               Globe Life Field in Arlington, Texas            8
# 19                Globe Life Field, Arlington, Texas.            9
#
#     response_time
# 0        4.032726
# 1        3.655848
# 2        2.885671
# 3        5.749361
# 4        1.972559
# 5        2.019986
# 6        6.648883
# 7        3.771706
# 8        1.946911
# 9        5.047650
# 10       2.483595
# 11       5.489367
# 12       3.740212
# 13       4.153864
# 14       4.521991
# 15       4.360824
# 16       5.582134
# 17       6.197276
# 18       4.015148
# 19       4.067360

# %%
# токенов в сек на моей 4070 SUPER
file['token_count'].sum() / file['response_time'].sum()
# Out:
# 14.36672191729925
