# %%
import pandas as pd

# %%
file = pd.read_json("data.json", orient='index')
file
# Out:
#                                              response  token_count  \
# 0                  Globe Life Field, Arlington, Texas            8
# 1                  Globe Life Field, Arlington, Texas            8
# 2   The World Series in 2020 was played at Globe L...           44
# 3   Game 6 of the 2020 World Series was played at ...           89
# 4                Globe Life Field in Arlington, Texas            8
# 5   The 2020 World Series, between the Los Angeles...           71
# 6   The World Series games were played at Globe Li...          133
# 7   The 2020 World Series was played at Globe Life...           52
# 8   The 2020 World Series was played at Globe Life...           66
# 9   In Game 6 of the 2020 World Series, the Los An...          117
# 10  The 2020 World Series was played at Globe Life...           77
# 11              Globe Life Field in Arlington, Texas.            9
# 12               Globe Life Field in Arlington, Texas            8
# 13  The World Series in 2020 was played at Globe L...           53
# 14                 Globe Life Field, Arlington, Texas            8
# 15  The World Series games in 2020 were played at ...           97
# 16  The 2020 World Series was played at Globe Life...           52
# 17              Globe Life Field in Arlington, Texas.            9
# 18  The World Series in 2020 was played at Globe L...           68
# 19  The 2020 World Series was played at Globe Life...          124
#
#     response_time
# 0       17.837688
# 1       23.027607
# 2       19.064296
# 3       20.405098
# 4       18.051079
# 5       20.262561
# 6       22.028688
# 7       20.639987
# 8       22.622262
# 9       24.306382
# 10      23.332468
# 11      22.426999
# 12      22.742692
# 13      24.512379
# 14      23.286902
# 15      26.375846
# 16      25.056768
# 17      24.692063
# 18      26.618118
# 19      27.804072

# %%
# токенов в сек на моей 4070 SUPER
file['token_count'].sum() / file['response_time'].max()
# Out:
# 39.59851607636019
